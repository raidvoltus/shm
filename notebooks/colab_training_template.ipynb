# %% [markdown]
# # IDX Bot — Colab Training Job (optional)
#
# This notebook is a **template** for optional remote training.
# It is not required for SIGNAL mode.
#
# 1. Pull job spec JSON produced by `ColabComputeProvider`.
# 2. Train within the 19-minute budget.
# 3. Write validated result JSON + model artifact with SHA-256.
# 4. Never embed secrets. Never return arbitrary pickle without checksum metadata.

# %%
# Placeholder — wire to your private job queue / GitHub artifact flow.
print('Colab template only — production uses LocalComputeProvider by default.')
